# %%
import torch

# %%
x = torch.randn(3, 5)
print(x)
# Out:
# tensor([[ 1.0053,  1.1220,  0.9858, -0.5233,  1.5268],
#         [ 0.2527, -1.0417,  0.1487,  0.8124,  0.0711],
#         [ 0.6169, -0.9361, -1.5268,  1.2719, -0.3274]])

# %%
y = torch.softmax(x, dim=1)
print(y)
# Out:
# tensor([[0.1998, 0.2245, 0.1959, 0.0433, 0.3365],
#         [0.2101, 0.0576, 0.1894, 0.3677, 0.1752],
#         [0.2745, 0.0581, 0.0322, 0.5285, 0.1068]])
