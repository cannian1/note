# %%
import torch
import torch.nn as nn

# %%
# 随机失活
x = torch.randint(1, 10, (10,), dtype=torch.float32)

# %%
# 定义一个Dropout层
dropout = nn.Dropout(p=0.5)  # 概率 0.5 关闭神经元，其余的神经元值等比例增加

# %%
y = dropout(x)

# %%
print(x)
print(y)
# Out:
# tensor([3., 4., 6., 9., 3., 6., 1., 2., 3., 5.])
# tensor([ 6.,  0.,  0., 18.,  6., 12.,  2.,  4.,  6., 10.])
